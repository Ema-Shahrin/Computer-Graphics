# %%
import matplotlib.pyplot as plt

# %%
x1,y1 = 1,1
x2,y2 = 4,3

# %%
dx = x2 -x1
dy = y2 -y1
m = dy/dx
print(m)
# Out:
# 0.6666666666666666

# %%
xi = x1
yi = y1

points = []

# %%
points.append((x1,y1))
while xi!=x2 and yi!=y2:
  if (abs(dx)>=abs(dy)):
    xi=xi+1
    yi=yi+m
  else:
    yi=yi+1
    xi=xi+(1/m)
  
  points.append((xi,yi))

points.append((x2,y2))

# %%
print(points)

x = [ points[0] for point in points]
y = [ points[1] for point in points]

plt.plot(x,y,color='b',marker='o')
plt.grid(True)
plt.show()
# Out:
# [(1, 1), (2, 1.6666666666666665), (3, 2.333333333333333), (4, 2.9999999999999996), (4, 3), (4, 3), (4, 3), (4, 3)]
